# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm
import pickle

# %%
DataDir = 'ignore_folder/PetImages'
Categories = ['Cat', 'Dog']

# %%
for category in Categories:  # do dogs and cats
    path = os.path.join(DataDir,category)  # create path to dogs and cats
    for img in os.listdir(path):  # iterate over each image per dogs and cats
        img_array = cv2.imread(os.path.join(path,img) ,cv2.IMREAD_GRAYSCALE)  # convert to array
        plt.imshow(img_array, cmap='gray')  # graph it
        plt.show()  # display!

        break  # we just want one for now so break
    break  #...and one more!

# %%
print(img_array)
# Out:
# [[174 175 177 ... 134 133 132]
#  [175 176 178 ... 135 134 132]
#  [177 178 179 ... 137 136 134]
#  ...
#  [ 56  55  58 ... 168 165 174]
#  [ 57  56  58 ... 157 150 153]
#  [ 58  56  58 ... 156 143 139]]

# %%
IMG_SIZE = 100

new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
plt.imshow(new_array, cmap= 'gray')
plt.show()

# %%
training_data = []

# Categories = ['Cat', 'Dog'] => Categories[0] = 'Cat' Categories[1] = 'Dog'

def create_training_data():
    for category in Categories:  # do dogs and cats
        path = os.path.join(DataDir,category)  # create path to dogs and cats
        class_num = Categories.index(category)  # the classifier needs to be a number insead of a string
        for img in os.listdir(path):  # iterate over each image per dogs and cats
            try:  # try just incase one of the pictures is 'broken'
                img_array = cv2.imread(os.path.join(path,img) ,cv2.IMREAD_GRAYSCALE)  # convert to array
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                training_data.append([new_array, class_num])
            except Exception as e:
                pass

# %%
create_training_data()

# %%
print(len(training_data))
# Out:
# 24946

# %%
import random

# %%
random.shuffle(training_data)

# %%
for sample in training_data[:10]:
    print(sample[1])
# Out:
# 1
# 1
# 0
# 1
# 1
# 0
# 0
# 0
# 1
# 0

# %%
train_X = []
train_y = []

# %%
for features, label in training_data:
    train_X.append(features)
    train_y.append(label)

train_X = np.array(train_X).reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
pickle_out = open('ignore_folder/train_X.pickle', 'wb')
pickle.dump(train_X, pickle_out)
pickle_out.close()

# %%
pickle_out = open('ignore_folder/train_y.pickle', 'wb')
pickle.dump(train_y, pickle_out)
pickle_out.close()

# %%
pickle_in = open('ignore_folder/train_X.pickle', 'rb')
X_train = pickle.load(pickle_in)

# %%
X_train[0]
# Out:
# array([[[138],
#         [187],
#         [162],
#         ...,
#         [121],
#         [123],
#         [132]],
#
#        [[127],
#         [193],
#         [154],
#         ...,
#         [118],
#         [124],
#         [127]],
#
#        [[127],
#         [185],
#         [159],
#         ...,
#         [115],
#         [118],
#         [123]],
#
#        ...,
#
#        [[161],
#         [162],
#         [164],
#         ...,
#         [175],
#         [190],
#         [158]],
#
#        [[160],
#         [160],
#         [161],
#         ...,
#         [172],
#         [188],
#         [156]],
#
#        [[162],
#         [164],
#         [162],
#         ...,
#         [166],
#         [157],
#         [177]]], dtype=uint8)
